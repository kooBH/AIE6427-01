# %%
import matplotlib.pyplot as plt   
import numpy as np

# %%
TRT = np.load("../rawnet3/TRT.npy")
torch = np.load("../rawnet3/pytorch.npy")
print(TRT.shape)
print(torch.shape)
# Out:
# (1, 256)
# (1, 256)

# %%
plt.figure()
plt.plot(TRT[0]-torch[0])
